# %% [markdown]
# # 🗺️ TavilyMap & TavilyExtract Tutorial
#
# > **📚 Part of the LangChain Course: Building AI Agents & RAG Apps**
# > [🎓 Get the full course](https://www.udemy.com/course/langchain/?referralCode=D981B8213164A3EA91AC)
#
#
# This notebook demonstrates two powerful tools from Tavily AI:
# - **TavilyMap**: Automatically discovers and maps website structures
# - **TavilyExtract**: Extracts clean, structured content from web pages
#
# Perfect for documentation scraping, research, and content extraction! 🚀
#
# ---

# %% [markdown]
# ## 📦 Setup & Installation
#
# First, let's install the required packages and set up our environment.

# %%
# Install required packages
# !pip install langchain-tavily certifi

# For pretty printing and visualization
# !pip install rich pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-tavily
#   Downloading langchain_tavily-0.2.18-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: certifi in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (2026.1.4)
# Collecting aiohttp<4.0.0,>=3.11.14 (from langchain-tavily)
#   Downloading aiohttp-3.14.1-cp314-cp314-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: langchain<2.0.0,>=1.0.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain-tavily) (1.3.7)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.11 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain-tavily) (1.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain-tavily) (2.32.5)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading propcache-0.5.2-cp314-cp314-win_amd64.whl.metadata (17 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading yarl-1.24.2-cp314-cp314-win_amd64.whl.metadata (97 kB)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.4 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain<2.0.0,>=1.0.0->langchain-tavily) (1.2.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain<2.0.0,>=1.0.0->langchain-tavily) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.8.7)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (4.13.0)
# Requirement already satisfied: httpcore==1.* in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.0.9)
# Requirement already satisfied: idna in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (2.6.3)
# Downloading langchain_tavily-0.2.18-py3-none-any.whl (30 kB)
# Downloading aiohttp-3.14.1-cp314-cp314-win_amd64.whl (485 kB)
# Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl (45 kB)
# Downloading yarl-1.24.2-cp314-cp314-win_amd64.whl (94 kB)
# Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl (44 kB)
# Downloading propcache-0.5.2-cp314-cp314-win_amd64.whl (42 kB)
# Installing collected packages: propcache, multidict, frozenlist, aiohappyeyeballs, yarl, aiosignal, aiohttp, langchain-tavily
#
#    ----- ---------------------------------- 1/8 [multidict]
#    ----- ---------------------------------- 1/8 [multidict]
#    --------------- ------------------------ 3/8 [aiohappyeyeballs]
#    -------------------- ------------------- 4/8 [yarl]
#    -------------------- ------------------- 4/8 [yarl]
#    -------------------- ------------------- 4/8 [yarl]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ------------------------------ --------- 6/8 [aiohttp]
#    ----------------------------------- ---- 7/8 [langchain-tavily]
#    ----------------------------------- ---- 7/8 [langchain-tavily]
#    ---------------------------------------- 8/8 [langchain-tavily]
#
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.1 aiosignal-1.4.0 frozenlist-1.8.0 langchain-tavily-0.2.18 multidict-6.7.1 propcache-0.5.2 yarl-1.24.2
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rich in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (14.3.3)
# Requirement already satisfied: pandas in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from rich) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from rich) (2.20.0)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from pandas) (2026.1)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: six>=1.5 in C:\Users\mbatt\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import asyncio
import os
import ssl
from typing import Any, Dict, List

import certifi
from langchain_tavily import TavilyExtract, TavilyMap
from rich.console import Console
from rich.panel import Panel

# Configure SSL context
ssl_context = ssl.create_default_context(cafile=certifi.where())
os.environ["SSL_CERT_FILE"] = certifi.where()
os.environ["REQUESTS_CA_BUNDLE"] = certifi.where()

# Initialize rich console for pretty printing
console = Console()


print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %% [markdown]
# ## 🔑 API Key Setup
#
# You'll need a Tavily API key to use these tools. Get yours at [tavily.com](https://app.tavily.com/home?utm_campaign=eden_marco&utm_medium=socials&utm_source=linkedin).
#
# Set environment variable `TAVILY_API_KEY`

# %%
# Set directly (uncomment and add your key)
# tavily_api_key = "your_tavily_api_key_here"

os.environ["TAVILY_API_KEY"] = "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"

# %% [markdown]
# ## 🗺️ TavilyMap: Website Structure Discovery
#
# TavilyMap automatically discovers and maps website structures by crawling through links. It's perfect for:
# - Documentation sites
# - Blog archives
# - Knowledge bases
# - Any structured website
#
# ### Key Parameters:
# - `max_depth`: How deep to crawl (default: 3)
# - `max_breadth`: How many links per page (default: 10)
# - `max_pages`: Maximum total pages to discover (default: 100)

# %%
# Initialize TavilyMap with custom settings
tavily_map = TavilyMap(
    max_depth=3,        # Crawl up to 3 levels deep
    max_breadth=15,     # Follow up to 15 links per page
    max_pages=50        # Limit to 50 total pages for demo
)

print("✅ TavilyMap initialized successfully!")
# Out:
# ✅ TavilyMap initialized successfully!

# %% [markdown]
# ### 📊 Demo: Mapping a Documentation Site
#
# Let's map the structure of a popular documentation site. We'll use the FastAPI documentation as an example.

# %%
# Example website to map
demo_url = "https://python.langchain.com/docs/introduction/"

console.print(f"🔍 Mapping website structure for: {demo_url}", style="bold blue")
console.print("This may take a moment...")

# Map the website structure
site_map = tavily_map.invoke(demo_url)

# Display results
urls = site_map.get('results', [])
console.print(f"\n✅ Successfully mapped {len(urls)} URLs!", style="bold green")

# Show first 10 URLs as examples
console.print("\n📋 First 50 discovered URLs:", style="bold yellow")
for i, url in enumerate(urls[:50], 1):
    console.print(f"  {i:2d}. {url}")

if len(urls) > 10:
    console.print(f"  ... and {len(urls) - 50} more URLs")
# Out:
# 🔍 Mapping website structure for: https://python.langchain.com/docs/introduction/
# This may take a moment...
# ✅ Successfully mapped 22 URLs!
# 📋 First 50 discovered URLs:
#    1. https://python.langchain.com/docs/introduction
#    2. https://python.langchain.com/use-these-docs
#    3. https://python.langchain.com/build-overview
#    4. https://python.langchain.com/llms.txt
#    5. https://python.langchain.com/langsmith/trace-with-langchain
#    6. https://python.langchain.com/langsmith/observability
#    7. https://python.langchain.com/langsmith/engine
#    8. https://python.langchain.com/oss/python/learn
#    9. https://python.langchain.com/oss/python/langchain/runtime
#   10. https://python.langchain.com/oss/python/langchain/retrieval
#   11. https://python.langchain.com/oss/python/langchain/messages
#   12. https://python.langchain.com/oss/python/langchain/observability
#   13. https://python.langchain.com/oss/python/langchain/studio
#   14. https://python.langchain.com/oss/python/langchain/overview
#   15. https://python.langchain.com/oss/python/langchain/tools
#   16. https://python.langchain.com/oss/python/langchain/models
#   17. https://python.langchain.com/oss/python/langgraph/overview
#   18. https://python.langchain.com/oss/python/langchain/guardrails
#   19. https://python.langchain.com/oss/python/langchain/ui
#   20. https://python.langchain.com/oss/python/langchain/deploy
#   21. https://python.langchain.com/oss/python/langchain/long-term-memory
#   22. https://python.langchain.com/oss/python/langchain/streaming
#   ... and -28 more URLs

# %% [markdown]
# ## 🔍 TavilyExtract: Clean Content Extraction
#
# TavilyExtract takes URLs and returns clean, structured content without ads, navigation, or other noise. Perfect for:
# - Documentation processing
# - Content analysis
# - Research and data collection
# - Building knowledge bases
#
# ### Key Features:
# - Removes HTML markup and navigation
# - Extracts main content only
# - Handles JavaScript-rendered content
# - Batch processing support

# %%
# Initialize TavilyExtract
tavily_extract = TavilyExtract()

print("✅ TavilyExtract initialized successfully!")
# Out:
# ✅ TavilyExtract initialized successfully!

# %% [markdown]
# ### 📄 Demo: Extracting Content from URLs
#
# Let's extract clean content from some of the URLs we discovered earlier.

# %%
# Select a few interesting URLs for extraction
sample_urls = [urls[15]]  # Take first 5 URLs
console.print(f"📚 Extracting content from {len(sample_urls)} URLs...", style="bold blue")

# Extract content
extraction_result = await tavily_extract.ainvoke(input={"urls": sample_urls})

# Display results
extracted_docs = extraction_result.get('results', [])
console.print(f"\n✅ Successfully extracted {len(extracted_docs)} documents!", style="bold green")

# Show summary of each extracted document
for i, doc in enumerate(extracted_docs, 1):
    url = doc.get('url', 'Unknown')
    content = doc.get('raw_content', '')

    # Create a panel for each document
    panel_content = f"""URL: {url}
Content Length: {len(content):,} characters
Preview: {content}..."""

    console.print(Panel(panel_content, title=f"Document {i}", border_style="blue"))
    print()  # Add spacing
# Out:
# 📚 Extracting content from 1 URLs...
# ✅ Successfully extracted 1 documents!
# ╭────────────────────────────────────────────────── Document 1 ───────────────────────────────────────────────────╮
# │ URL: https://python.langchain.com/oss/python/langchain/models                                                   │
# │ Content Length: 6,007 characters                                                                                │
# │ Preview: > ## Documentation Index                                                                               │
# │ >                                                                                                               │
# │ > Fetch the complete documentation index at: </llms.txt>                                                        │
# │ >                                                                                                               │
# │ > Use this file to discover all available pages before exploring further.                                       │
# │                                                                                                                 │
# │ Join our product experts for a "Build More with LangSmith: Summer AMA Series" from July 9-August 12, 2026.      │
# │ [RSVP today](https://events.langchain.com/ama-series/build-more-with-langsmith/)                                │
# │                                                                                                                 │
# │ [Docs by LangChain home                                                                                         │
# │ page!(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max │
# │ &auto=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)!(https://mintcdn.com/langchain-5e9cc07 │
# │ a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=0bc │
# │ d2a1f2599ed228bcedf0f535b45b1)](/)                                                                              │
# │                                                                                                                 │
# │ [Overview](/build-overview)[Deep                                                                                │
# │ Agents](/oss/python/deepagents/overview)[LangChain](/oss/python/langchain/overview)[LangGraph](/oss/python/lang │
# │ graph/overview)[Integrations](/oss/python/integrations/providers/overview)[Learn](/oss/python/learn)[Reference] │
# │ (/oss/python/reference/overview)[Contribute](/oss/python/contributing/overview)                                 │
# │                                                                                                                 │
# │ # LangChain overview                                                                                            │
# │                                                                                                                 │
# │ LangChain provides create\_agent: a minimal, highly configurable agent harness. Compose exactly the agent your  │
# │ use case needs from model, tools, prompt, and middleware.                                                       │
# │                                                                                                                 │
# │ **Agent = Model + Harness.** LangChain provides `create_agent`: a minimal, highly configurable harness. The     │
# │ harness is everything around the model loop: the prompt, the tools, and any middleware that shapes behavior.    │
# │ Start with the primitives and compose exactly what your use case needs. Supports [OpenAI, Anthropic, Google,    │
# │ and more](/oss/python/integrations/providers/overview).                                                         │
# │                                                                                                                 │
# │ **LangChain vs. LangGraph vs. Deep Agents**Start with [Deep Agents](/oss/python/deepagents/overview) for a      │
# │ “batteries-included” agent with features like automatic context compression, a virtual filesystem, and          │
# │ subagent-spawning. Deep Agents are built on LangChain (/oss/python/langchain/agents) which you can also use     │
# │ directly.Use [LangChain](/oss/python/langchain/agents) (`create_agent`) for a highly customizable harness,      │
# │ easily tailored to your use case and data.Use [LangGraph](/oss/python/langgraph/overview), our low-level        │
# │ orchestration framework, for advanced needs combining deterministic and agentic workflows.Use                   │
# │ [LangSmith](/langsmith/observability) to trace, debug, and evaluate agents built with any of these frameworks.  │
# │ Follow the (/langsmith/trace-with-langchain) to get set up. We recommend you also set up [LangSmith             │
# │ Engine](/langsmith/engine) which monitors your traces, detects issues, and proposes fixes.                      │
# │                                                                                                                 │
# │ ## [​](#create-an-agent) Create an agent                                                                         │
# │                                                                                                                 │
# │ This example demonstrates how to create a simple LangChain agent with a custom tool:                            │
# │                                                                                                                 │
# │ ```                                                                                                             │
# │ # pip install -qU langchain "langchain"# pip install -qU langchain "langchain"from langchain.agents import      │
# │ create_agent from  langchain. agents import  create_agent def get_weather(city: str) -> str: def                │
# │ get_weather(city:  str) ->  str: """Get weather for a given city.""" """Get weather for a given city.""" return │
# │ f"It's always sunny in {city}!"  return  f "It's always sunny in {city}!" agent = create_agent(agent =          │
# │ create_agent( model="openai:gpt-5.5",  model ="openai:gpt-5.5", tools=,  tools =, system_prompt="You are a      │
# │ helpful assistant",  system_prompt = "You are a helpful assistant",)) result = agent.invoke(result =  agent.    │
# │ invoke( {"messages": [{"role": "user", "content": "What's the weather in San Francisco?"}]} {"messages":        │
# │ [{"role":  "user",  "content":  "What's the weather in San                                                      │
# │ Francisco?"}]}))print(result["messages"][-1].content_blocks) print(result[" messages "][- 1]. content_blocks)   │
# │ ```                                                                                                             │
# │                                                                                                                 │
# │ See the [Installation instructions](/oss/python/langchain/install) and [Quickstart                              │
# │ guide](/oss/python/langchain/quickstart) to get started building your own agents and applications with          │
# │ LangChain.                                                                                                      │
# │                                                                                                                 │
# │ Use [LangSmith](/langsmith/observability) to trace requests, debug agent behavior, and evaluate outputs. Set    │
# │ `LANGSMITH_TRACING=true` and your API key to get started.                                                       │
# │                                                                                                                 │
# │ ## [​](#core-benefits) Core benefits                                                                             │
# │                                                                                                                 │
# │ ## Standard model interface                                                                                     │
# │                                                                                                                 │
# │ Use one interface for chat models, embeddings, and more across providers. Switch models with minimal code       │
# │ changes and keep your application portable as requirements evolve.                                              │
# │                                                                                                                 │
# │ ## Highly configurable harness                                                                                  │
# │                                                                                                                 │
# │ Start with `create_agent` as a minimal harness and add capabilities incrementally through middleware. Compose   │
# │ only what your use case needs, from guardrails and retries to routing and custom tool policies.                 │
# │                                                                                                                 │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n │
# │ =nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81)                                                      │
# │                                                                                                                 │
# │ ## Built on top of LangGraph                                                                                    │
# │                                                                                                                 │
# │ LangChain’s agents are built on top of LangGraph. This allows us to take advantage of LangGraph’s durable       │
# │ execution, human-in-the-loop support, persistence, and more.                                                    │
# │                                                                                                                 │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto │
# │ =format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc)                                             │
# │                                                                                                                 │
# │ ## Debug with LangSmith                                                                                         │
# │                                                                                                                 │
# │ Inspect traces, tool calls, state transitions, and latency in one place. Find failure modes, evaluate quality,  │
# │ and improve agent behavior with execution data.                                                                 │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ [Connect these docs](/use-these-docs) to Claude, VSCode, and more via MCP for real-time answers.                │
# │                                                                                                                 │
# │ [Edit this page on GitHub](https://github.com/langchain-ai/docs/edit/main/src/oss/langchain/overview.mdx) or    │
# │ (https://github.com/langchain-ai/docs/issues/new/choose).                                                       │
# │                                                                                                                 │
# │ Was this page helpful?                                                                                          │
# │                                                                                                                 │
# │ [Install LangChain](/oss/python/langchain/install)...                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### ⚡ Batch Processing Demo
#
# For larger datasets, we can process URLs in batches to optimize performance and handle rate limits.

# %%
def chunk_urls(urls: List[str], chunk_size: int = 3) -> List[List[str]]:
    """Split URLs into chunks of specified size."""
    chunks = []
    for i in range(0, len(urls), chunk_size):
        chunk = urls[i:i + chunk_size]
        chunks.append(chunk)
    return chunks

async def extract_batch(urls: List[str], batch_num: int) -> List[Dict[str, Any]]:
    """Extract documents from a batch of URLs."""
    try:
        console.print(f"🔄 Processing batch {batch_num} with {len(urls)} URLs", style="blue")
        docs = await tavily_extract.ainvoke(input={"urls": urls})
        results = docs.get('results', [])
        console.print(f"✅ Batch {batch_num} completed - extracted {len(results)} documents", style="green")
        return results
    except Exception as e:
        console.print(f"❌ Batch {batch_num} failed: {e}", style="red")
        return []

# Process a larger set of URLs in batches
url_batches = chunk_urls(urls[:9], chunk_size=3) # Take first 9 URLs for batch demo, split to batches of 3

console.print(f"📦 Processing 9 URLs in {len(url_batches)} batches", style="bold yellow")

# Process batches concurrently
tasks = [extract_batch(batch, i + 1) for i, batch in enumerate(url_batches)]
batch_results = await asyncio.gather(*tasks)

# Flatten results
all_extracted = []
for batch_result in batch_results:
    all_extracted.extend(batch_result)

console.print(f"\n🎉 Batch processing complete! Total documents extracted: {len(all_extracted)}", style="bold green")
# Out:
# 📦 Processing 9 URLs in 3 batches
# 🔄 Processing batch 1 with 3 URLs
# 🔄 Processing batch 2 with 3 URLs
# 🔄 Processing batch 3 with 3 URLs
# ✅ Batch 3 completed - extracted 3 documents
# ✅ Batch 1 completed - extracted 3 documents
# ✅ Batch 2 completed - extracted 3 documents
# 🎉 Batch processing complete! Total documents extracted: 9

# %% [markdown]
# ## 🎯 Real-World Use Cases
#
# Here are some practical applications of TavilyMap and TavilyExtract:
#
# ### 1. Documentation Scraping
# - Map entire documentation sites
# - Extract clean content for search indexes
# - Build knowledge bases from existing docs
#
# ### 2. Competitive Analysis
# - Map competitor websites
# - Extract product information
# - Monitor content changes
#
# ### 3. Research & Content Collection
# - Gather information from multiple sources
# - Build datasets for analysis
# - Create content archives
#
# ### 4. SEO & Site Analysis
# - Discover all pages on a site
# - Analyze content structure
# - Identify content gaps

# %% [markdown]
# ## 🎯 Conclusion
#
# This tutorial demonstrated the power of TavilyMap and TavilyExtract for automated web content discovery and extraction:
#
# ### Key Takeaways:
#
# 1. **TavilyMap** is perfect for:
#    - Discovering website structures
#    - Finding all pages on a site
#    - Site auditing
#
# 2. **TavilyExtract** excels at:
#    - Clean content extraction
#    - Removing HTML noise
#    - Batch processing
#    - Structured data collection
#
# 3. **Combined** they enable:
#    - Complete documentation scraping
#    - Automated content pipelines
#    - Knowledge base creation
#    - Research automation
#
# ### Next Steps:
# - Integrate with vector databases for semantic search
# - Add content filtering and classification
# - Build monitoring systems for content changes
# - Create automated reporting dashboards
#
# ---
#
# **Happy scraping!** 🚀
